# %% [raw]
# PYCARET IN DEPTH DISCUSSION

# %%
#CREATE A NEW ENVIRONMENT NAMED PYcaret or of Your Choice

# %%
#LOADING DAtaset from Pycaret
from pycaret.datasets import get_data

# %%
df=get_data("diabetes")
# Out:
#    Number of times pregnant  \
# 0                         6
# 1                         1
# 2                         8
# 3                         1
# 4                         0
#
#    Plasma glucose concentration a 2 hours in an oral glucose tolerance test  \
# 0                                                148
# 1                                                 85
# 2                                                183
# 3                                                 89
# 4                                                137
#
#    Diastolic blood pressure (mm Hg)  Triceps skin fold thickness (mm)  \
# 0                                72                                35
# 1                                66                                29
# 2                                64                                 0
# 3                                66                                23
# 4                                40                                35
#
# ...

# %%
from pycaret.classification import * #* means importing all the libraries present in classification

# %%
clf=setup(data=df,target='Class variable')
# Out:
#
# Setup Succesfully Completed!
# <style  type="text/css" >
# </style><table id="T_26021662_d035_11ea_bc41_00f48da2985c" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Description</th>        <th class="col_heading level0 col1" >Value</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_26021662_d035_11ea_bc41_00f48da2985clevel0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_26021662_d035_11ea_bc41_00f48da2985crow0_col0" class="data row0 col0" >session_id</td>
#                         <td id="T_26021662_d035_11ea_bc41_00f48da2985crow0_col1" class="data row0 col1" >8771</td>
#             </tr>
#             <tr>
#                         <th id="T_26021662_d035_11ea_bc41_00f48da2985clevel0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_26021662_d035_11ea_bc41_00f48da2985crow1_col0" class="data row1 col0" >Target Type</td>
# ...

# %%
#COMPARING MODELS
compare_models()
# Out:
# <style  type="text/css" >
#     #T_5e1417e2_d035_11ea_887f_00f48da2985c th {
#           text-align: left;
#     }    #T_5e1417e2_d035_11ea_887f_00f48da2985crow0_col0 {
#             text-align:  left;
#         }    #T_5e1417e2_d035_11ea_887f_00f48da2985crow0_col1 {
#             background-color:  yellow;
#             text-align:  left;
#         }    #T_5e1417e2_d035_11ea_887f_00f48da2985crow0_col2 {
#             : ;
#             text-align:  left;
#         }    #T_5e1417e2_d035_11ea_887f_00f48da2985crow0_col3 {
#             : ;
#             text-align:  left;
#         }    #T_5e1417e2_d035_11ea_887f_00f48da2985crow0_col4 {
#             background-color:  yellow;
#             text-align:  left;
#         }    #T_5e1417e2_d035_11ea_887f_00f48da2985crow0_col5 {
#             : ;
#             text-align:  left;
#         }    #T_5e1417e2_d035_11ea_887f_00f48da2985crow0_col6 {
#             : ;
#             text-align:  left;
# ...

# %% [raw]
# REGRESSION PROBLEM

# %%
data=get_data('boston')
# Out:
#       crim    zn  indus  chas    nox     rm   age     dis  rad  tax  ptratio  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#     black  lstat  medv
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# 3  394.63   2.94  33.4
# 4  396.90   5.33  36.2

# %%
from pycaret.regression import *

# %%
reg=setup(data=data,target='medv')
# Out:
#
# Setup Succesfully Completed!
# <style  type="text/css" >
# </style><table id="T_7576d4c6_d036_11ea_971e_00f48da2985c" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Description</th>        <th class="col_heading level0 col1" >Value</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_7576d4c6_d036_11ea_971e_00f48da2985clevel0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_7576d4c6_d036_11ea_971e_00f48da2985crow0_col0" class="data row0 col0" >session_id</td>
#                         <td id="T_7576d4c6_d036_11ea_971e_00f48da2985crow0_col1" class="data row0 col1" >3406</td>
#             </tr>
#             <tr>
#                         <th id="T_7576d4c6_d036_11ea_971e_00f48da2985clevel0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_7576d4c6_d036_11ea_971e_00f48da2985crow1_col0" class="data row1 col0" >Transform Target </td>
# ...

# %%
compare_models()
# Out:
# <style  type="text/css" >
#     #T_d4560d26_d036_11ea_abe9_00f48da2985c th {
#           text-align: left;
#     }    #T_d4560d26_d036_11ea_abe9_00f48da2985crow0_col0 {
#             text-align:  left;
#         }    #T_d4560d26_d036_11ea_abe9_00f48da2985crow0_col1 {
#             : ;
#             text-align:  left;
#         }    #T_d4560d26_d036_11ea_abe9_00f48da2985crow0_col2 {
#             background-color:  yellow;
#             text-align:  left;
#         }    #T_d4560d26_d036_11ea_abe9_00f48da2985crow0_col3 {
#             background-color:  yellow;
#             text-align:  left;
#         }    #T_d4560d26_d036_11ea_abe9_00f48da2985crow0_col4 {
#             text-align:  left;
#         }    #T_d4560d26_d036_11ea_abe9_00f48da2985crow0_col5 {
#             : ;
#             text-align:  left;
#         }    #T_d4560d26_d036_11ea_abe9_00f48da2985crow0_col6 {
#             : ;
#             text-align:  left;
#         }    #T_d4560d26_d036_11ea_abe9_00f48da2985crow1_col0 {
# ...

# %%
reg_model=create_model('catboost')
# Out:
#          MAE      MSE    RMSE      R2   RMSLE    MAPE
# 0     2.5998  20.0559  4.4784  0.7226  0.1634  0.1185
# 1     1.5530   5.1619  2.2720  0.9313  0.0943  0.0707
# 2     2.5086  11.1693  3.3421  0.9146  0.1691  0.1380
# 3     2.0380   8.8883  2.9813  0.9088  0.1025  0.0821
# 4     2.0623   6.5242  2.5542  0.8995  0.1662  0.1295
# 5     1.9551   9.0055  3.0009  0.8761  0.1426  0.1066
# 6     1.3444   2.9421  1.7153  0.9536  0.1006  0.0762
# 7     2.1586   7.0256  2.6506  0.9005  0.1405  0.1133
# 8     2.7251  13.5844  3.6857  0.8466  0.1322  0.1154
# 9     1.9738   7.5218  2.7426  0.9209  0.1629  0.1241
# Mean  2.0919   9.1879  2.9423  0.8874  0.1374  0.1074
# SD    0.4150   4.5963  0.7285  0.0616  0.0277  0.0221

# %%
reg_model

# %%
reg_model.get_params()
# Out:
# {'loss_function': 'RMSE', 'silent': True, 'random_state': 3406}

# %%
#reg_model.predict()

# %%
#HYPER TUNING OF MODEL
reg_model_hypertune=tune_model('catboost',n_iter=50,optimize='mae')
# Out:
#          MAE      MSE    RMSE      R2   RMSLE    MAPE
# 0     2.5399  20.1783  4.4920  0.7209  0.1577  0.1104
# 1     1.7118   6.1141  2.4727  0.9186  0.0986  0.0743
# 2     2.7144  11.7209  3.4236  0.9104  0.1611  0.1420
# 3     1.9837   7.1191  2.6682  0.9270  0.0974  0.0807
# 4     1.9860   5.4131  2.3266  0.9166  0.1505  0.1232
# 5     1.8343  10.2056  3.1946  0.8595  0.1533  0.1043
# 6     1.3131   2.5241  1.5887  0.9602  0.0874  0.0723
# 7     1.9178   5.6571  2.3785  0.9199  0.1403  0.1077
# 8     2.7344  16.1369  4.0171  0.8177  0.1444  0.1201
# 9     2.0692   8.4014  2.8985  0.9116  0.1820  0.1350
# Mean  2.0805   9.3471  2.9460  0.8863  0.1373  0.1070
# SD    0.4325   5.1161  0.8172  0.0665  0.0301  0.0233
